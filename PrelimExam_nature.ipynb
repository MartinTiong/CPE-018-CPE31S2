# %% [markdown]
# <a href="https://colab.research.google.com/github/MartinTiong/CPE-018-CPE31S2/blob/main/PrelimExam_nature.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import cv2 as cv
import matplotlib.pyplot as plt

# %%
path = cv2.imread('/content/drive/MyDrive/EMTECH/nature.jpg')
image = cv2.imread('/content/drive/MyDrive/EMTECH/nature.jpg')

# %%
image = cv2.resize(image, (300, 300))

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image, cmap='gray')
plt.show()

# %%
print(image.shape)
# Out:
# (300, 300)
